# %%
import pandas as pd
df_students = pd.read_csv(r"C:\Users\ASUS\Downloads\StudentsPerformance.csv")

# %%
df_students.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(df_students['math score'])
plt.title('Distribution of Math Score')
plt.show()

# %%
df_students_encoded = pd.get_dummies(df_students, columns = ['gender', 'race/ethnicity'])
