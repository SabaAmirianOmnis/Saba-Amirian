# %%
import pandas as pd
import matplotlib.pyplot as plt




df = pd.read_csv(r"C:\Users\ASUS\Downloads\Titanic.csv")




df.groupby("PassengerId")["Survived"].mean().plot(kind = "bar")
plt.title("Survival Rate by PassengerId")
plt.show()
