# %%
import pandas as pd
df_medical = pd.read_csv(r"C:\Users\ASUS\Downloads\insurance.csv")

# %%
df_medical.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
import matplotlib.pyplot as plt
plt.hist(df_medical['charges'])
plt.title('Distribution of Charges')
plt.show()

# %%
df_medical_encoded = pd.get_dummies(df_medical, columns = ['age', 'charges'])
