# %%
import pandas as pd
import matplotlib.pyplot as plt



data = {"Age":[30, 45, 25, 60, 35, 50, 28, 55], "Gender":["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female"], "BloodPressure":[120, 140, 115, 150, 130, 145, 118, 135], "HealthStatus":["Healthy", "Unhealthy", "Healthy", "Unhealthy", "Healthy", "Unhealthy", "Healthy", "Unhealthy"]}



df = pd.DataFrame(data)



print("Average Age:", df["Age"].mean())
print("Number of Healthy Patients:", df["HealthStatus"].value_counts()["Healthy"])



plt.scatter(df["Age"], df["BloodPressure"], color = "blue", label = "Patients")
plt.title("Age vs Blood Pressure")
plt.xlabel("Age (Years)")
plt.ylabel("Blood Pressurs (mmHg)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Average Age: 41.0
# Number of Healthy Patients: 4
