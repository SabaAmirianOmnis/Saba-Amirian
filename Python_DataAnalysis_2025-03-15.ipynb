# %%
import pandas as pd
import matplotlib.pyplot as plt



df = pd.read_csv(r"C:\Users\ASUS\Documents\Study_Data.csv")



print("Original DataFrame:")
print(df)



plt.plot(df["Hours Studied"], df["Pass (1=Yes, 0=No)"], marker="o", color="green")
plt.title("Study Hours vs Pass/Fail")
plt.xlabel("Hours Studied")
plt.ylabel("Pass(1=Yes, 0=No)")
plt.grid(True)
plt.show()
# Out:
# Original DataFrame:
#    Hours Studied  Pass (1=Yes, 0=No)
# 0            1.0                   0
# 1            1.5                   0
# 2            2.0                   0
# 3            2.5                   1
# 4            3.0                   1
# 5            3.5                   1
# 6            4.0                   1
# 7            4.5                   1
