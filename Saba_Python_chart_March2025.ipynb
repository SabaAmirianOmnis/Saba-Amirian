# %%
import matplotlib.pyplot as plt

categories = [ 'Apples' , 'Bananas' , 'Oranges' ]
values = [ 30 , 40 , 30 ]

plt.pie( values , labels = categories , autopct = '%1.1f%%' , colors = [ '#FF9999' , '#66B2FF' , '#99FF99'])
plt.title ( 'Fruit Distribution' )

plt.show()
