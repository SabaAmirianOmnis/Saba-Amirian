# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt




df = pd.read_csv(r"C:\Users\ASUS\Downloads\Medical.csv")




df['smoker'] = df['smoker'].map({'yes' : 1, 'no' : 0})
X = df[['age', 'bmi', 'smoker']]




scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)




kmeans = KMeans(n_clusters = 3, random_state = 42)
df['cluster'] = kmeans.fit_predict(X_scaled)




plt.figure(figsize = (8, 6))
plt.scatter(df['age'], df['bmi'], c = df['cluster'], cmap = 'viridis')
plt.title('K-Means Clustering of Medical Cost Data')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.colorbar(label = 'Cluster')
plt.show()




print("Cluster Centers (scaled) :")
print(kmeans.cluster_centers_)
# Out:
# Cluster Centers (scaled) :
# [[ 0.8569633  -0.49074242 -0.03154626]
#  [ 0.31596259  1.1980611   0.1069294 ]
#  [-0.96340765 -0.40726027 -0.04698259]]
