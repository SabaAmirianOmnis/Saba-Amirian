# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt




df = pd.read_csv(r"C:\Users\ASUS\Downloads\Medical.csv")




df['smoker'] = df['smoker'].map({'yes' : 1,'no' : 0})




X = df[['age', 'bmi', 'smoker']]




scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)




pca = PCA(n_components = 2)
X_pca = pca.fit_transform(X_scaled)




plt.figure(figsize = (8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c = df['charges'], cmap = 'viridis')
plt.title('PCA of Medical Cost Data')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label = 'Charges')
plt.show()




print("Explained Variance Ratio :", pca.explained_variance_ratio_)
# Out:
# Explained Variance Ratio : [0.37044603 0.33387679]
